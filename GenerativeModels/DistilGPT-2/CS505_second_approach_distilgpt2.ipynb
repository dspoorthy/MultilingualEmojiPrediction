# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Training mGPT on Twitter Emoji Daataset

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install datasets
# !pip install pytorch-lightning
# !pip install wandb

# %%
import wandb

wandb.init(project="CS505-DistilGPT2", entity="sks99")
# Out:
# wandb: Currently logged in as: sks99 (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220501_214132-2ld03ygs</code>
# Syncing run <strong><a href="https://wandb.ai/sks99/CS505-DistilGPT2/runs/2ld03ygs" target="_blank">worldly-cosmos-6</a></strong> to <a href="https://wandb.ai/sks99/CS505-DistilGPT2" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/sks99/CS505-DistilGPT2/runs/2ld03ygs?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
from transformers import pipeline

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained('google/mt5-small')
# model = TFMT5Model.from_pretrained('google/mt5-small').cuda()
tokenizer = AutoTokenizer.from_pretrained('distilgpt2')
model = AutoModelForCausalLM.from_pretrained('distilgpt2').to(device)
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]

# %%
# #### Step 1: Tokenize the input into integer token IDs
# inputs = tokenizer.encode("Hello, how are you?", return_tensors='pt').to(model.device)
# print("Input Token IDs: " + str(inputs))

# %%
# context = "Hello, how are you?"
# encoded_input = tokenizer(
#     context,
#     padding='max_length',
#     max_length=16,
#     truncation=True,
#     return_tensors="pt",
# ).to(model.device)
# decoder_input = tokenizer(
#     context,
#     padding='max_length',
#     max_length=16,
#     truncation=True,
#     return_tensors="pt",
# ).to(model.device)

# %%
# #### Step 2 and 3: Feed in the integer token IDs and get out a sequence of token IDs as output
# outputs = model.generate(input_ids=encoded_input["input_ids"], decoder_input_ids=decoder_input["input_ids"])
# print("Output Token IDs: " + str(outputs))

# %%
# encoded_input

# %%
# #### Step 4: Feed in the integer token IDs and get out a sequence of token IDs as output
# output_text = [tokenizer.decode(x) for x in outputs]
# print("Output Text: " + str(output_text))

# %%
def read_from_file(filename):
    file = open(filename,"r")
    vocab = file.read().splitlines()
    return vocab

# %%
es_train_data_path = "/content/drive/MyDrive/505/Project Data/train/spanish/tweet_by_ID_30_4_2022__02_47_48.txt.text"
es_train_labels_path = "/content/drive/MyDrive/505/Project Data/train/spanish/tweet_by_ID_30_4_2022__02_47_48.txt.labels"
es_train_data = read_from_file(es_train_data_path)
es_train_labels = read_from_file(es_train_labels_path)

# %%
en_train_data_path = "/content/drive/MyDrive/505/Project Data/train/english/tweet_by_ID_30_4_2022__04_17_45.txt.text"
en_train_labels_path = "/content/drive/MyDrive/505/Project Data/train/english/tweet_by_ID_30_4_2022__04_17_45.txt.labels"
en_train_data = read_from_file(en_train_data_path)
en_train_labels = read_from_file(en_train_labels_path)

# %%
def combine_data_labels(data, labels, labels_map):
  combined_data = []
  for i, tweet in enumerate(data):
    tweet = tweet.split(' ')
    tweet.append(labels_map[int(labels[i])].upper())
    combined_data.append(' '.join(tweet))
  return combined_data

# %%
import pandas as pd
def get_emoji_mappings():
  mapping_path = '/content/drive/MyDrive/505/Project Data/mapping/consolidated_mapping.txt'
  emoji_df = pd.read_csv(mapping_path, sep='\t', names=['emoji','emoji_code', 'smt'])

  emoji_label_map = {}
  for emj_idx in range(len(emoji_df['emoji_code'])):
    emoji_label_map[emj_idx] = "<" + emoji_df['emoji_code'][emj_idx] + ">"
  # print(emoji_df)
  return emoji_label_map

# %%
emoji_label_map = get_emoji_mappings()

# %%
es_train_data_combined = combine_data_labels(es_train_data, es_train_labels, emoji_label_map)
en_train_data_combined = combine_data_labels(en_train_data, en_train_labels, emoji_label_map)

# %%
es_train_data_combined[1]
# Out:
# 'Disfrutando de buena comida con buena compañía (@ Cátame Despacito in Murcia)  <_FIRE_>'

# %%
import pandas as pd

es_train_data_combined_df = pd.DataFrame(es_train_data_combined, columns=['Tweet'])
en_train_data_combined_df = pd.DataFrame(en_train_data_combined, columns=['Tweet'])

# %%
es_train_data_combined_df.to_csv("/content/drive/MyDrive/505/project/es_train_data_combined.csv")
en_train_data_combined_df.to_csv("/content/drive/MyDrive/505/project/en_train_data_combined.csv")

# %%
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling
import datasets
from datasets import load_dataset, list_datasets

# %%
tokenizer.pad_token = tokenizer.eos_token
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
def encode(batch): 
  input_ids = tokenizer([x.strip('\n\r') for x in batch['Tweet']], truncation=True, padding=True)
  # return {"input_ids": input_ids["input_ids"], "decoder_input_ids": input_ids["input_ids"], "attention_mask": input_ids['attention_mask']}
  return input_ids

es_train = load_dataset("csv", data_files='drive/MyDrive/505/project/es_train_data_combined.csv', split='train')
processed = es_train.map(encode, batched=True, batch_size=len(es_train)//5)
processed.set_format('torch', columns=['input_ids', 'attention_mask'])
# Out:
# Using custom data configuration default-0047c9ec3e00185b
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-0047c9ec3e00185b/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
len(processed)
# Out:
# 81165

# %%
# model.config.pad_token_id = model.config.eos_token_id

# %%
training_args = TrainingArguments(
    output_dir='/content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish',
    overwrite_output_dir=True,
    num_train_epochs=4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    logging_steps=100,
    weight_decay=0.01,
    # save_total_limit=1,
    logging_dir='/content/drive/MyDrive/505/project/DistilGPT2/Logs',
)

trainer = Trainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    data_collator=data_collator,
    train_dataset=processed
)

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `GPT2LMHeadModel.forward` and have been ignored: Tweet, Unnamed: 0. If Tweet, Unnamed: 0 are not expected by `GPT2LMHeadModel.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 81165
#   Num Epochs = 4
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20292
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='20292' max='20292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20292/20292 1:00:31, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>3.879100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>3.365600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>3.264900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>3.161900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>3.098300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>3.066600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>3.016900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>2.980000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>2.916600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.915500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>2.893900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>2.858200</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>2.868700</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>2.841400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.835400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>2.784300</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>2.779900</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>2.770800</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>2.745000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.734300</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>2.739200</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>2.696700</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>2.709600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>2.697800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.720000</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>2.723500</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>2.655400</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>2.691700</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>2.628000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.655400</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>2.679200</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>2.651400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>2.639000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>2.645600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.612900</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>2.631900</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>2.622600</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>2.573500</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>2.584200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.586900</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>2.636400</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>2.572600</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>2.564600</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>2.605300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.560200</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>2.560800</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>2.562300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>2.522000</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>2.543400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.566800</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>2.541100</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>2.450700</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>2.514300</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>2.463000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.478000</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>2.490000</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>2.486200</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>2.471200</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>2.493800</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.419800</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>2.440400</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>2.475500</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>2.462200</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>2.447500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.432700</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>2.461100</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>2.437400</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>2.481600</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>2.436700</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.433200</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>2.460400</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>2.429600</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>2.432100</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>2.429200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>2.450300</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>2.425300</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>2.407200</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>2.428300</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>2.398600</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>2.440400</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>2.422400</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>2.405900</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>2.418300</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>2.436600</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>2.407800</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>2.413200</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>2.407200</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>2.436600</td>
#     </tr>
#     <tr>
#       <td>8900</td>
#       <td>2.398200</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.416400</td>
#     </tr>
#     <tr>
#       <td>9100</td>
#       <td>2.423100</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>2.410100</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>2.390400</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>2.403100</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>2.414700</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>2.354700</td>
#     </tr>
#     <tr>
#       <td>9700</td>
#       <td>2.399300</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>2.382200</td>
#     </tr>
#     <tr>
#       <td>9900</td>
#       <td>2.383100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.390000</td>
#     </tr>
#     <tr>
#       <td>10100</td>
#       <td>2.389400</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>2.314100</td>
#     </tr>
#     <tr>
#       <td>10300</td>
#       <td>2.310300</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>2.354700</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>2.345600</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>2.356800</td>
#     </tr>
#     <tr>
#       <td>10700</td>
#       <td>2.317600</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>2.347000</td>
#     </tr>
#     <tr>
#       <td>10900</td>
#       <td>2.335100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>2.347700</td>
#     </tr>
#     <tr>
#       <td>11100</td>
#       <td>2.337900</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>2.379700</td>
#     </tr>
#     <tr>
#       <td>11300</td>
#       <td>2.347200</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>2.313100</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>2.335900</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>2.369800</td>
#     </tr>
#     <tr>
#       <td>11700</td>
#       <td>2.338200</td>
#     </tr>
#     <tr>
#       <td>11800</td>
#       <td>2.338900</td>
#     </tr>
#     <tr>
#       <td>11900</td>
#       <td>2.312700</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>2.326600</td>
#     </tr>
#     <tr>
#       <td>12100</td>
#       <td>2.352900</td>
#     </tr>
#     <tr>
#       <td>12
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-6500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-7500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-8500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-9500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-10500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-11500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-12500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-13500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-14500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-15500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-16500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-17500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-18500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19500
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19500/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-19500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000
# Configuration saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000/config.json
# Model weights saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=20292, training_loss=2.4485340731256278, metrics={'train_runtime': 3631.9849, 'train_samples_per_second': 89.389, 'train_steps_per_second': 5.587, 'total_flos': 8947188602634240.0, 'train_loss': 2.4485340731256278, 'epoch': 4.0})

# %%
distilgpt2 = pipeline('text-generation', model='/content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000', device=-1)
# gpt2 = pipeline('text-generation', model='gpt2', device=0)

# %%
x = "@user dedeu como está hoy de limpia la plaza?"
# test = distilgpt2(x)
# print(gpt2('Saint Petersburg is'))

# %%
test[0]['generated_text']
# Out:
# 'Welcome to New York @ Times Square New York City  <_TWO_HEARTS_> - #tourismandtheworld #traveller #travel…  <_FACE_WITH_TEARS_OF_JOY'

# %%
model_path = '/content/drive/MyDrive/505/project/DistilGPT2/Outputs/Spanish/checkpoint-20000'
model_test = AutoModelForCausalLM.from_pretrained(model_path, pad_token_id=tokenizer.eos_token_id).to(device)

# %%
x = "Buenos días desde Valencia en Comunidad Valenciana, Spain"
input_ids = tokenizer.encode(x, return_tensors='pt').to(device)

# generate text until the output length (which includes the context length) reaches 50
greedy_output = model_test.generate(input_ids, max_length=len(input_ids[0])+max_len).to(device)

decoded_op = tokenizer.decode(greedy_output[0], skip_special_tokens=True)

print("Output:\n" + 100 * '-')
print(decoded_op)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Buenos días desde Valencia en Comunidad Valenciana, Spain  <_SMILING_FACE_WITH_HEARTEYES_> @user  <_SMILING_EYES_>_>  <_SM

# %%
len(input_ids[0])
# Out:
# 10

# %%
s = '<'
i = 0
t = ''
while('>' not in t):
  t = tokenizer.decode(greedy_output[0][len(input_ids[0])+2+i], skip_special_tokens=True)
  s += t
  i += 1
print(s)
# Out:
# <_RED_HEART_>

# %%
def find_max_len_emoji(mapping):
  emojis = mapping.values()
  max_len = 0
  for emoji in emojis:
    if len(emoji) > max_len:
      max_len = len(emoji)

  return (max_len)

# %%
max_len = find_max_len_emoji(mapping=emoji_label_map)

# %%
max_len
# Out:
# 34

# %%
es_test_data_path = "/content/drive/MyDrive/505/Project Data/test/es_test.text"
es_test_labels_path = "/content/drive/MyDrive/505/Project Data/test/es_test.labels"
es_test_data = read_from_file(es_test_data_path)
es_test_labels = read_from_file(es_test_labels_path)

# %%
def get_emoji_names(labels, mapping):
  new_labels = []
  for label in labels:
    emoji = mapping[int(label)].upper()
    new_labels.append(emoji[2:-2])
  return new_labels

# %%
es_test_labels = get_emoji_names(es_test_labels, emoji_label_map)

# %%
import re
from tqdm import tqdm
def test_data(data, labels):
  test_acc = 0
  for i in tqdm(range(len(data))):
    # test = distilgpt2(tweet)
    # gen_text = test[0]['generated_text'].split(' ')
    # gen_text = [word for word in gen_text if len(word) != 0]
    input_ids = tokenizer.encode(data[i], return_tensors='pt').to(device)

    # generate text until the output length (which includes the context length) reaches 50
    greedy_output = model_test.generate(input_ids, max_length=len(input_ids[0])+160).to(device)

    decoded_op = tokenizer.decode(greedy_output[0], skip_special_tokens=True)
    # decoded_op = distilgpt2(tweet)
    # decoded_op = decoded_op[0]['generated_text']
    # print(decoded_op)
    # if '<' not in decoded_op:
    #   continue
    # print(i)
    regex = re.search('<_(.+?)_>', decoded_op)
    if regex:
        gen_emoji = regex.group(1)
    # print(gen_emoji, labels[i])
    if gen_emoji == labels[i]:
      test_acc += 1
  return (test_acc * 100 / len(labels))

# %%
test_acc = test_data(es_test_data, es_test_labels)
print()
print("Testing accuracy:", test_acc)
# Out:
# 100%|██████████| 10000/10000 [2:08:18<00:00,  1.30it/s]
# Testing accuracy: 33.96

# %%
for i, tweet in enumerate(es_test_data[:5]):
    # test = distilgpt2(tweet)
    # gen_text = test[0]['generated_text'].split(' ')
    # gen_text = [word for word in gen_text if len(word) != 0]
    input_ids = tokenizer.encode(tweet, return_tensors='pt').to(device)

    # generate text until the output length (which includes the context length) reaches 50
    greedy_output = model_test.generate(input_ids, max_length=len(input_ids[0])+max_len).to(device)

    decoded_op = tokenizer.decode(greedy_output[0], skip_special_tokens=True)
    # print("Output:\n" + 100 * '-')
    print(decoded_op)
    # if '<' not in gen_text:
    #   continue
    # print(gen_text)
# Out:
# Buenos días desde Valencia en Comunidad Valenciana, Spain  <_SMILING_FACE_WITH_HEARTEYES_> @user  <_SMILING_EYES_>_>  <_SM
# Anoche en la #prefería con @user,mi prima evazappoz y #Juan.Bien empezamos,bien #sur…  <_SMILING_FACE_WITH_HEARTEYES_>  <_SMILING_EYES_>_>_>  <_SMIL
# Porfavor llevarlas a reciclar,necesitamos más papel para imprimir más propaganda. @user  <_SMILING_FACE_WITH_HEARTEYES_>  <_SMILING_EYES_>_>  <_
# El vecino roquero que todos queremos tener en PasswordLearn #PuertaDelSol #PuertaDelSol…  <_SMILING_FACE_WITH_HEARTEYES_>  <
# Es un placer contar con profesionales del sector de vuestra talla... gracias!!! ️@NukleeBCN @user  <_RED_HEART_>  <_RED_HEART_>_>  <_RED_HEART_>_>_>  <_RED_HEART

# %%
input_ids = tokenizer.encode(es_test_data[0], return_tensors='pt').to(device)

# generate text until the output length (which includes the context length) reaches 50
greedy_output = model_test.generate(input_ids, max_length=len(input_ids[0])+max_len).to(device)

decoded_op = tokenizer.decode(greedy_output[0], skip_special_tokens=True)

m = re.search('<_(.+?)_>', decoded_op)
if m:
    found = m.group(1)
print(found)
# Out:
# SMILING_FACE_WITH_HEARTEYES

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
